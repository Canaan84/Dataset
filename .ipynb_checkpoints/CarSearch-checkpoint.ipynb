# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import random
import pickle
import statsmodels.api as sm
from scipy.optimize import minimize
from sklearn.linear_model import LinearRegression
from linearmodels import PanelOLS, PooledOLS, IV2SLS

# %%
import os
os.chdir("C:/Users/Canaan/Downloads")

# %%
df = pd.read_csv('TitleRequest20230701041605/INC7628889_20150101_20150630.csv', header=None)
# Out:
# C:\Users\Canaan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (5,8,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707953 entries, 0 to 707952
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       707953 non-null  object
#  1   1       707953 non-null  object
#  2   2       707921 non-null  object
#  3   3       707953 non-null  object
#  4   4       707953 non-null  object
#  5   5       707953 non-null  object
#  6   6       674074 non-null  float64
#  7   7       707950 non-null  object
#  8   8       707953 non-null  object
#  9   9       707953 non-null  object
#  10  10      707953 non-null  object
#  11  11      707951 non-null  object
#  12  12      707952 non-null  object
#  13  13      707950 non-null  object
#  14  14      707578 non-null  object
#  15  15      14 non-null      float64
#  16  16      5 non-null       float64
# dtypes: float64(3), object(14)
# memory usage: 91.8+ MB

# %%
df.head()
# Out:
#                   0     1                2   3              4        5   \
# 0  1HD1BWV14FB025806    HD               --  MC    ROAD/STREET  22492.7
# 1  1HD1KRM19FB629953    HD               --  MC    ROAD/STREET    29044
# 2  1FADP3F20DL339908  FORD         FOCUS SE  4D      FOUR DOOR    13050
# 3  1J8GN58K29W535563  JEEP               --  SW  STATION WAGON    12000
# 4  2GTEC19T421184446   GMC  SIERRA C1500SIE  PT   PICKUP TRUCK     6995
#
#          6        7   8         9                 10              11  12  \
# 0       5.0  26:44.0  88  MN000079   350 TARHE TRAIL  UPPER SANDUSKY  OH
# 1       7.0  39:47.0  88  MN000079   350 TARHE TRAIL  UPPER SANDUSKY  OH
# 2   27683.0  49:43.0  56  ND000549   117 E CHURCH ST      WOODSFIELD  OH
# 3   56224.0  48:28.0  83  UD001050  714 COLUMBUS AVE         LEBANON  OH
# 4  111339.0  48:33.0  83  UD001050  714 COLUMBUS AVE         LEBANON  OH
#
#       13     14  15  16
# 0  43351  45867 NaN NaN
# 1  43351  43466 NaN NaN
# 2  43793  43793 NaN NaN
# 3  45036  45068 NaN NaN
# 4  45036  45103 NaN NaN

# %%
columName = ["VIN", "make", "model", "BT", "BTD", "price", "mileage", "date", "countyCode",
             "dealerNum", "dealerST", "dealerCity", "dealerState", "dealerZIP", "ownerZIP"]

# %%
df = df.iloc[:, :(-2)]
df.columns = columName

# %%
pd.to_numeric(df['price']).astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "ALL TERRAIN"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-27e9bf903e09> in <module>
# ----> 1 pd.to_numeric(df['price']).astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     147         coerce_numeric = errors not in ("ignore", "raise")
#     148         try:
# --> 149             values = lib.maybe_convert_numeric(
#     150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "ALL TERRAIN" at position 368109

# %%
df.head()
# Out:
#                  VIN  make            model  BT            BTD    price  \
# 0  1HD1BWV14FB025806    HD               --  MC    ROAD/STREET  22492.7
# 1  1HD1KRM19FB629953    HD               --  MC    ROAD/STREET    29044
# 2  1FADP3F20DL339908  FORD         FOCUS SE  4D      FOUR DOOR    13050
# 3  1J8GN58K29W535563  JEEP               --  SW  STATION WAGON    12000
# 4  2GTEC19T421184446   GMC  SIERRA C1500SIE  PT   PICKUP TRUCK     6995
#
#     mileage     date countyCode dealerNum          dealerST      dealerCity  \
# 0       5.0  26:44.0         88  MN000079   350 TARHE TRAIL  UPPER SANDUSKY
# 1       7.0  39:47.0         88  MN000079   350 TARHE TRAIL  UPPER SANDUSKY
# 2   27683.0  49:43.0         56  ND000549   117 E CHURCH ST      WOODSFIELD
# 3   56224.0  48:28.0         83  UD001050  714 COLUMBUS AVE         LEBANON
# 4  111339.0  48:33.0         83  UD001050  714 COLUMBUS AVE         LEBANON
#
#   dealerState dealerZIP ownerZIP
# 0          OH     43351    45867
# 1          OH     43351    43466
# 2          OH     43793    43793
# 3          OH     45036    45068
# 4          OH     45036    45103

# %%
zipcross = pd.read_csv('ZipCodetoZCTACrosswalk2015UDS (1).csv')
zipcross = zipcross[["ZIP", "ZCTA_USE"]]

# %%
df.merge(zipcross, left_on='ownerZIP', right_on='ZIP')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-1516c9c5835d> in <module>
# ----> 1 df.merge(zipcross, left_on='ownerZIP', right_on='ZIP')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7282         from pandas.core.reshape.merge import merge
#    7283
# -> 7284         return merge(
#    7285             self,
#    7286             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     629         # validate the merge keys dtypes. We may need to coerce
#     630         # to avoid incompat dtypes
# --> 631         self._maybe_coerce_merge_keys()
#     632
#     633         # If argument passed to validate,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1144                     inferred_right in string_types and inferred_left not in string_types
#    1145                 ):
# -> 1146                     raise ValueError(msg)
#    1147
#    1148             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
zipcross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41250 entries, 0 to 41249
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ZIP       41250 non-null  int64
#  1   ZCTA_USE  41250 non-null  int64
# dtypes: int64(2)
# memory usage: 644.7 KB
